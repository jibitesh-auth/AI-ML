# %%
# !pip install pandas

# %%
import pandas as pd

# %%
info = {
    "Name": ["Rahul","Ankita","Jibitesh"],
    "CGPA": [9.5,10,9.9]
}
df = pd.DataFrame(info)
df
# Out:
#        Name  CGPA
# 0     Rahul   9.5
# 1    Ankita  10.0
# 2  Jibitesh   9.9

# %%
df = pd.DataFrame(info, ["A","B","C"])
df
# Out:
#        Name  CGPA
# A     Rahul   9.5
# B    Ankita  10.0
# C  Jibitesh   9.9
